# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pl
import matplotlib.pyplot as plt

# %%
loc = "/content/drive/MyDrive/WEATHER FORCHASTING/final_cleaned_data.csv"

df = pd.read_csv(loc)
df = df.drop(columns = ['Evaporation (mm)'], axis = 1)

# %%
df.head(3)
# Out:
#    Max/Temp0C (7.30 A.M)  Min/Temp0C (7.30 A.M)  Dry Bulb/Temp0C (7.30 A.M)  \
# 0                   26.0                   20.0                        28.0
# 1                   26.5                   19.5                        28.5
# 2                   26.0                   19.0                        28.5
#
#    Wet Bulb/Temp0C (7.30 A.M)  Max/Temp0C (2.30 P.M)  Min/Temp0C (2.30 P.M)  \
# 0                        21.5                   36.0                   26.0
# 1                        20.5                   35.0                   24.0
# 2                        21.0                   32.0                   28.5
#
#    Dry Bulb/Temp0C (2.30 P.M)  Wet Bulb/Temp0C (2.30 P.M)  \
# 0                        34.5                        28.5
# 1                        30.5                        26.5
# 2                        31.5                        26.0
#
#    7.30 A.M/Wind direction  2.30 P.M/Wind direction  Wind Speed (km/hr)    WS  \
# ...

# %%
for feature in df.columns:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(15,15))

# %%
IQR=df['Max/Temp0C (7.30 A.M)'].quantile(0.75)-df['Max/Temp0C (7.30 A.M)'].quantile(0.25)
lower_bridge=df['Max/Temp0C (7.30 A.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['Max/Temp0C (7.30 A.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 19.25 33.25

# %%
df.loc[df['Max/Temp0C (7.30 A.M)']>=33.25,'Max/Temp0C (7.30 A.M)']=33.25
df.loc[df['Max/Temp0C (7.30 A.M)']<=19.25,'Max/Temp0C (7.30 A.M)']=19.25

# %%
IQR=df['Min/Temp0C (7.30 A.M)'].quantile(0.75)-df['Min/Temp0C (7.30 A.M)'].quantile(0.25)
lower_bridge=df['Min/Temp0C (7.30 A.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['Min/Temp0C (7.30 A.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 16.25 26.25

# %%
df.loc[df['Min/Temp0C (7.30 A.M)']>=26.25,'Min/Temp0C (7.30 A.M)']=26.25
df.loc[df['Min/Temp0C (7.30 A.M)']<=16.25,'Min/Temp0C (7.30 A.M)']=16.25

# %%
IQR=df['Dry Bulb/Temp0C (7.30 A.M)'].quantile(0.75)-df['Dry Bulb/Temp0C (7.30 A.M)'].quantile(0.25)
lower_bridge=df['Dry Bulb/Temp0C (7.30 A.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['Dry Bulb/Temp0C (7.30 A.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 18.5 34.5

# %%
df.loc[df['Dry Bulb/Temp0C (7.30 A.M)']>=34.5,'Dry Bulb/Temp0C (7.30 A.M)']=34.5
df.loc[df['Dry Bulb/Temp0C (7.30 A.M)']<=18.5,'Dry Bulb/Temp0C (7.30 A.M)']=18.5

# %%
IQR=df['Wet Bulb/Temp0C (7.30 A.M)'].quantile(0.75)-df['Wet Bulb/Temp0C (7.30 A.M)'].quantile(0.25)
lower_bridge=df['Wet Bulb/Temp0C (7.30 A.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['Wet Bulb/Temp0C (7.30 A.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 17.5 25.5

# %%
df.loc[df['Wet Bulb/Temp0C (7.30 A.M)']>=25.5,'Wet Bulb/Temp0C (7.30 A.M)']=25.5
df.loc[df['Wet Bulb/Temp0C (7.30 A.M)']<=17.5,'Wet Bulb/Temp0C (7.30 A.M)']=17.5

# %%
IQR=df['Max/Temp0C (2.30 P.M)'].quantile(0.75)-df['Max/Temp0C (2.30 P.M)'].quantile(0.25)
lower_bridge=df['Max/Temp0C (2.30 P.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['Max/Temp0C (2.30 P.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 28.5 44.5

# %%
df.loc[df['Max/Temp0C (2.30 P.M)']>=44.5,'Max/Temp0C (2.30 P.M)']=44.5
df.loc[df['Max/Temp0C (2.30 P.M)']<=28.5,'Max/Temp0C (2.30 P.M)']=28.5

# %%
IQR=df['Min/Temp0C (2.30 P.M)'].quantile(0.75)-df['Min/Temp0C (2.30 P.M)'].quantile(0.25)
lower_bridge=df['Min/Temp0C (2.30 P.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['Min/Temp0C (2.30 P.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 23.5 31.5

# %%
df.loc[df['Min/Temp0C (2.30 P.M)']>=31.5,'Min/Temp0C (2.30 P.M)']=31.5
df.loc[df['Min/Temp0C (2.30 P.M)']<=23.5,'Min/Temp0C (2.30 P.M)']=23.5

# %%
IQR=df['Dry Bulb/Temp0C (2.30 P.M)'].quantile(0.75)-df['Dry Bulb/Temp0C (2.30 P.M)'].quantile(0.25)
lower_bridge=df['Dry Bulb/Temp0C (2.30 P.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['Dry Bulb/Temp0C (2.30 P.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 29.25 43.25

# %%
df.loc[df['Dry Bulb/Temp0C (2.30 P.M)']>=43.25,'Dry Bulb/Temp0C (2.30 P.M)']=43.25
df.loc[df['Dry Bulb/Temp0C (2.30 P.M)']<=29.25,'Dry Bulb/Temp0C (2.30 P.M)']=29.25

# %%
IQR=df['Wet Bulb/Temp0C (2.30 P.M)'].quantile(0.75)-df['Wet Bulb/Temp0C (2.30 P.M)'].quantile(0.25)
lower_bridge=df['Wet Bulb/Temp0C (2.30 P.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['Wet Bulb/Temp0C (2.30 P.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 23.5 31.5

# %%
df.loc[df['Wet Bulb/Temp0C (2.30 P.M)']>=31.5,'Wet Bulb/Temp0C (2.30 P.M)']=31.5
df.loc[df['Wet Bulb/Temp0C (2.30 P.M)']<=23.5,'Wet Bulb/Temp0C (2.30 P.M)']=23.5

# %%
IQR=df['7.30 A.M/Wind direction'].quantile(0.75)-df['7.30 A.M/Wind direction'].quantile(0.25)
lower_bridge=df['7.30 A.M/Wind direction'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['7.30 A.M/Wind direction'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -3.0 5.0

# %%
df.loc[df['7.30 A.M/Wind direction']>=5.0,'7.30 A.M/Wind direction']=5.0
df.loc[df['7.30 A.M/Wind direction']<=-3.0,'7.30 A.M/Wind direction']=-3.0

# %%
IQR=df['2.30 P.M/Wind direction'].quantile(0.75)-df['2.30 P.M/Wind direction'].quantile(0.25)
lower_bridge=df['2.30 P.M/Wind direction'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['2.30 P.M/Wind direction'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -1.0 7.0

# %%
df.loc[df['2.30 P.M/Wind direction']>=7.0,'2.30 P.M/Wind direction']=7.0
df.loc[df['2.30 P.M/Wind direction']<=-1.0,'2.30 P.M/Wind direction']=-1.0

# %%
IQR=df['Wind Speed (km/hr)'].quantile(0.75)-df['Wind Speed (km/hr)'].quantile(0.25)
lower_bridge=df['Wind Speed (km/hr)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['Wind Speed (km/hr)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 1040696.5 1096036.5

# %%
df.loc[df['Wind Speed (km/hr)']>=1096036.5,'Wind Speed (km/hr)']=1096036.5
df.loc[df['Wind Speed (km/hr)']<=1040696.5,'Wind Speed (km/hr)']=1040696.5

# %%
IQR=df['WS'].quantile(0.75)-df['WS'].quantile(0.25)
lower_bridge=df['WS'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['WS'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# -0.9583333333333328 5.708333333333332

# %%
df.loc[df['WS']>=5.708333333333332,'WS']=5.708333333333332
df.loc[df['WS']<=-0.9583333333333328,'WS']=-0.9583333333333328

# %%
IQR=df['5 cm/Soil Temp 0C (7.30 A.M)'].quantile(0.75)-df['5 cm/Soil Temp 0C (7.30 A.M)'].quantile(0.25)
lower_bridge=df['5 cm/Soil Temp 0C (7.30 A.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['5 cm/Soil Temp 0C (7.30 A.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 18.0 34.0

# %%
df.loc[df['5 cm/Soil Temp 0C (7.30 A.M)']>=34.0,'5 cm/Soil Temp 0C (7.30 A.M)']=34.0
df.loc[df['5 cm/Soil Temp 0C (7.30 A.M)']<=18.0,'5 cm/Soil Temp 0C (7.30 A.M)']=18.0

# %%
IQR=df['10 cm/Soil Temp 0C (7.30 A.M)'].quantile(0.75)-df['10 cm/Soil Temp 0C (7.30 A.M)'].quantile(0.25)
lower_bridge=df['10 cm/Soil Temp 0C (7.30 A.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['10 cm/Soil Temp 0C (7.30 A.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 16.0 32.0

# %%
df.loc[df['10 cm/Soil Temp 0C (7.30 A.M)']>=32.0,'10 cm/Soil Temp 0C (7.30 A.M)']=32.0
df.loc[df['10 cm/Soil Temp 0C (7.30 A.M)']<=16.0,'10 cm/Soil Temp 0C (7.30 A.M)']=16.0

# %%
IQR=df['15 cm/Soil Temp 0C (7.30 A.M)'].quantile(0.75)-df['15 cm/Soil Temp 0C (7.30 A.M)'].quantile(0.25)
lower_bridge=df['15 cm/Soil Temp 0C (7.30 A.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['15 cm/Soil Temp 0C (7.30 A.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 20.0 36.0

# %%
df.loc[df['15 cm/Soil Temp 0C (7.30 A.M)']>=36.0,'15 cm/Soil Temp 0C (7.30 A.M)']=36.0
df.loc[df['15 cm/Soil Temp 0C (7.30 A.M)']<=20.0,'15 cm/Soil Temp 0C (7.30 A.M)']=20.0

# %%
IQR=df['5 cm/Soil Temp 0C (2.30 P.M)'].quantile(0.75)-df['5 cm/Soil Temp 0C (2.30 P.M)'].quantile(0.25)
lower_bridge=df['5 cm/Soil Temp 0C (2.30 P.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['5 cm/Soil Temp 0C (2.30 P.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 27.5 51.5

# %%
df.loc[df['5 cm/Soil Temp 0C (2.30 P.M)']>=51.5,'5 cm/Soil Temp 0C (2.30 P.M)']=51.5
df.loc[df['5 cm/Soil Temp 0C (2.30 P.M)']<=27.5,'5 cm/Soil Temp 0C (2.30 P.M)']=27.5

# %%
IQR=df['10 cm/Soil Temp 0C (2.30 P.M)'].quantile(0.75)-df['10 cm/Soil Temp 0C (2.30 P.M)'].quantile(0.25)
lower_bridge=df['10 cm/Soil Temp 0C (2.30 P.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['10 cm/Soil Temp 0C (2.30 P.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 28.0 44.0

# %%
df.loc[df['10 cm/Soil Temp 0C (2.30 P.M)']>=44.0,'10 cm/Soil Temp 0C (2.30 P.M)']=44.0
df.loc[df['10 cm/Soil Temp 0C (2.30 P.M)']<=28.0,'10 cm/Soil Temp 0C (2.30 P.M)']=28.0

# %%
IQR=df['15 cm/Soil Temp 0C (2.30 P.M)'].quantile(0.75)-df['15 cm/Soil Temp 0C (2.30 P.M)'].quantile(0.25)
lower_bridge=df['15 cm/Soil Temp 0C (2.30 P.M)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['15 cm/Soil Temp 0C (2.30 P.M)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 24.5 40.5

# %%
df.loc[df['15 cm/Soil Temp 0C (2.30 P.M)']>=40.5,'15 cm/Soil Temp 0C (2.30 P.M)']=40.5
df.loc[df['15 cm/Soil Temp 0C (2.30 P.M)']<=24.5,'15 cm/Soil Temp 0C (2.30 P.M)']=24.5

# %%
IQR=df['Evaporation (mm) (t-1)'].quantile(0.75)-df['Evaporation (mm) (t-1)'].quantile(0.25)
lower_bridge=df['Evaporation (mm) (t-1)'].quantile(0.25)-(IQR*1.5)
upper_bridge=df['Evaporation (mm) (t-1)'].quantile(0.75)+(IQR*1.5)
print(lower_bridge, upper_bridge)
# Out:
# 0.8000000000000012 10.399999999999999

# %%
df.loc[df['Evaporation (mm) (t-1)']>=10.399999999999999,'Evaporation (mm) (t-1)']=10.399999999999999
df.loc[df['Evaporation (mm) (t-1)']<=0.8000000000000012,'Evaporation (mm) (t-1)']=0.8000000000000012

# %%
for feature in df.columns:
    data=df.copy()
    sns.boxplot(data[feature])
    plt.title(feature)
    plt.figure(figsize=(15,15))

# %%
import seaborn as sns
plt.figure(figsize=(30,20))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
data = df.copy()

# %%
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error


import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
data1= data.copy()

# %%
data =  data.drop(columns = ["Evaporation (mm) (t-1)"],axis = 1)
data["Wind Speed (km/hr)"] = data["Wind Speed (km/hr)"]/ 100000
data1["Wind Speed (km/hr)"] = data1["Wind Speed (km/hr)"]/ 100000

# %%
data = data.drop(columns = ["WS"], axis = 1)
data1 = data1.drop(columns = ["WS"], axis = 1)
data.head()
# Out:
#    Max/Temp0C (7.30 A.M)  Min/Temp0C (7.30 A.M)  Dry Bulb/Temp0C (7.30 A.M)  \
# 0                   26.0                   20.0                        28.0
# 1                   26.5                   19.5                        28.5
# 2                   26.0                   19.0                        28.5
# 3                   24.0                   18.5                        24.5
# 4                   28.5                   19.5                        28.0
#
#    Wet Bulb/Temp0C (7.30 A.M)  Max/Temp0C (2.30 P.M)  Min/Temp0C (2.30 P.M)  \
# 0                        21.5                   36.0                   26.0
# 1                        20.5                   35.0                   24.0
# 2                        21.0                   32.0                   28.5
# 3                        19.5                   32.5                   26.5
# 4                        19.0                   34.5                   28.0
#
# ...

# %%
tcolumns = data.columns

# %%
scaler = StandardScaler()
scaler.fit(data)
# Out:
# StandardScaler()

# %%
scaler.mean_
# Out:
# array([26.21847507, 21.5271261 , 26.42228739, 21.75671554, 36.28944282,
#        27.70697947, 35.91454545, 27.98825165,  1.21994135,  2.80351906,
#        10.68224085, 26.1568915 , 24.13343109, 27.52492669, 39.65542522,
#        35.80691496, 32.58815249])

# %%
data = scaler.transform(data)

# %%
data = pd.DataFrame(data, columns =tcolumns)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
pca.fit(data)
# Out:
# PCA(n_components=3)

# %%
x_pca = pca.transform(data)

# %%
x_pca.shape
# Out:
# (341, 3)

# %%
test = pd.DataFrame(x_pca, columns = ["feature1","feature2","feature3"])

# %%
test["target"] = df["Evaporation (mm) (t-1)"]

# %%
test
# Out:
#      feature1  feature2  feature3    target
# 0    0.503354  0.005900  1.835196  6.000000
# 1    3.046336 -0.227384  2.576965  4.600000
# 2    2.916539 -0.636239  2.484038  4.000000
# 3    4.000368  0.308512  2.163792  4.866667
# 4    1.725809  0.317799  2.474658  4.488889
# ..        ...       ...       ...       ...
# 336  3.599807  0.218704 -0.984035  4.800000
# 337  2.395650  0.258894 -0.888420  6.000000
# 338  2.564275  0.369473 -1.975125  6.800000
# 339  1.834358  1.212838 -1.627352  6.000000
# 340  2.917410  0.134026 -1.416067  4.800000
#
# [341 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(test[['feature1', 'feature2', 'feature3']], test["target"] , test_size = .08)

# %% [markdown]
# ## TYPES OF REGRESSION MODELS

# %% [markdown]
# Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
lasso_reg = Lasso(alpha=1.0)

# %%
lasso_reg.fit(X_train, y_train)
# Out:
# Lasso()

# %%
y_pred = lasso_reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error( y_pred,y_test)
rmse = sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 1.7635718671624439

# %% [markdown]
# Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt_reg = DecisionTreeRegressor()

# %%
dt_reg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dt_reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error( y_pred,y_test)
rmse = sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 0.0

# %%
# import pickle
# with open('DecisionTreeRegressor_0_0_1000_data_3_featue.pk', 'wb') as file:
#     pickle.dump(dt_reg, file)

# %% [markdown]
# Support Vector Regression (SVR)

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
svr_reg = SVR(kernel='rbf', C=1.0, epsilon=0.1)

# %%
svr_reg.fit(X_train_scaled, y_train)
# Out:
# SVR()

# %%
y_pred = svr_reg.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error(y_pred,y_test)
rmse = sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 1.6763989386389806

# %% [markdown]
# Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_reg = RandomForestRegressor(n_estimators=3, random_state=0)

# %%
rf_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=3, random_state=0)

# %%
y_pred = rf_reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error(y_pred,y_test)
rmse = sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 0.7229805558150242

# %%
# import pickle
# with open('random_forst_regressor_ACCURACY_0_7229805558150242_PCA_3_1000_DATA_SET.pk', 'wb') as file:
#     pickle.dump(rf_reg, file)

# %%
rf_reg.score(X_test,y_test)
# Out:
# 0.8810449681595177

# %%
rf_reg.score(X_train,y_train)
# Out:
# 0.9673984787565095

# %% [markdown]
# ## LI REGULARIZATION

# %%
from sklearn import linear_model

# %%
alpha = 0.001  
model = Lasso(alpha=alpha, max_iter = 100000,tol = 0.1)

# %%
model.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.001, max_iter=100000, tol=0.1)

# %%
print(model.score(X_train, y_train))
print(model.score(X_test, y_test))
# Out:
# 0.3804555094542714
# 0.3603168903457209

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 2.8108346639756787

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error( y_pred,y_test)
rmse = sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 1.6765544023310663

# %% [markdown]
# ## L2 REGULARIZATION

# %%
from sklearn.linear_model import Ridge

# %%
ridge_reg = Ridge(alpha = 0.001, max_iter = 100, tol = .1)
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.001, max_iter=100, tol=0.1)

# %%
ridge_reg.score(X_test, y_test)
# Out:
# 0.3602838233066725

# %%
ridge_reg.score(X_train, y_train)
# Out:
# 0.3804557923140216

# %%
y_pred = ridge_reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error( y_pred,y_test)
rmse = sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 1.6765977347034742

# %% [markdown]
# Gradient Boosting Regression

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb_reg = GradientBoostingRegressor(n_estimators=300, learning_rate=0.0001, random_state=0)

# %%
gb_reg.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.0001, n_estimators=300,
#                           random_state=0)

# %%
y_pred = gb_reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error(y_pred,y_test)
rmse = sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 2.0825085975749285

# %% [markdown]
# ## XGBOOSTER START

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
xgb.__version__
# Out:
# '1.7.5'

# %%
reg = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# %%
reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=42, ...)

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 0.06139602548866654

# %%
import pickle
with open('XGBOOSTER_0.06139602548866654.pk', 'wb') as file:
    pickle.dump(reg, file)

# %% [markdown]
# #END XGBOOSTER

# %% [markdown]
# # RNN START

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
from keras.losses import mean_squared_error
from keras.optimizers import RMSprop
from keras import backend as K

# %%
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
import tensorflow as tf
from keras.layers import Activation

from keras.layers import Dropout

# %%
def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
model = Sequential()
model.add(SimpleRNN(32, input_shape=(X_train.shape[1], 1)))  
model.add(Dropout(0.5))
model.add(Dense(10))
model.add(Activation('linear'))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  simple_rnn_3 (SimpleRNN)    (None, 32)                1088
#
#  dropout_19 (Dropout)        (None, 32)                0
#
#  dense_25 (Dense)            (None, 10)                330
#
#  activation_11 (Activation)  (None, 10)                0
#
#  dense_26 (Dense)            (None, 1)                 11
#
# ...
# Total params: 1,429
# Trainable params: 1,429
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(
    X_train,y_train,  
    epochs=2000,
    validation_split=0.1
)
# Out:
# Epoch 1/2000
# 27/27 [==============================] - 2s 13ms/step - loss: 34.7563 - val_loss: 29.5269
# Epoch 2/2000
# 27/27 [==============================] - 0s 5ms/step - loss: 28.2977 - val_loss: 20.6919
# Epoch 3/2000
# 27/27 [==============================] - 0s 4ms/step - loss: 15.5983 - val_loss: 5.4865
# Epoch 4/2000
# 27/27 [==============================] - 0s 5ms/step - loss: 5.6108 - val_loss: 2.8614
# Epoch 5/2000
# 27/27 [==============================] - 0s 4ms/step - loss: 5.0233 - val_loss: 2.8067
# Epoch 6/2000
# 27/27 [==============================] - 0s 4ms/step - loss: 5.5165 - val_loss: 2.8239
# Epoch 7/2000
# 27/27 [==============================] - 0s 5ms/step - loss: 4.7594 - val_loss: 2.7655
# Epoch 8/2000
# 27/27 [==============================] - 0s 4ms/step - loss: 4.6474 - val_loss: 2.7174
# Epoch 9/2000
# 27/27 [==============================] - 0s 4ms/step - loss: 4.8712 - val_loss: 2.7148
# Epoch 10/2000
# ...

# %%
import matplotlib.pyplot as plt
loss_per_epoch = history.history['loss']
x = range(len(loss_per_epoch))
y1 = history.history['loss']
y2 = history.history['val_loss']
fig, ax = plt.subplots()
ax.plot(x, y1, label='loss')
ax.plot(x, y2, label='val_loss')
ax.set_xlabel('NO OF ITERATION')
ax.set_ylabel('THE ACCURACY VALUE')
ax.set_title('Two Datasets on Same Graph')
ax.legend()


plt.show()

# %%
y_pred = model.predict(X_test)

print("Predicted value:", y_pred)
# Out:
# 3/3 [==============================] - 0s 5ms/step
# Predicted value: [[3.1997042]
#  [4.752055 ]
#  [4.4996777]
#  [4.650559 ]
#  [4.814062 ]
#  [6.2202206]
#  [5.729237 ]
#  [7.6067257]
#  [6.869982 ]
#  [5.7732906]
#  [6.1824265]
#  [4.0653605]
#  [5.691374 ]
#  [5.673486 ]
#  [6.1913776]
#  [7.3240237]
#  [3.0781362]
#  [5.034514 ]
#  [5.078068 ]
#  [7.3405275]
#  [5.419854 ]
#  [7.4367256]
#  [4.7330832]
#  [7.253366 ]
#  [7.6315584]
#  [5.0032883]
#  [5.610968 ]
#  [5.4506807]
#  [3.1997042]
#  [6.1913776]
#  [5.6623116]
#  [7.6067266]
#  [5.96151  ]
#  [7.1927323]
#  [3.6484354]
#  [3.3335402]
#  [4.3853703]
#  [6.0300965]
#  [7.54158  ]
#  [5.67151  ]
#  [5.4416223]
#  [4.300437 ]
#  [7.8718414]
#  [3.8193932]
#  [4.2012672]
#  [4.660969 ]
#  [5.80634  ]
#  [4.078516 ]
#  [6.8757563]
#  [5.905664 ]
#  [3.9838903]
#  [4.845508 ]
#  [4.033357 ]
#  [3.1897447]
#  [4.1151404]
#  [7.40135  ]
#  [4.2045836]
#  [5.786753 ]
#  [4.752055 ]
#  [5.4493175]
#  [7.2751474]
#  [6.1869392]
# ...

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 1.6810103273353916

# %%
# import pickle
# with open('RNN_1_2170772595309371.pk', 'wb') as file:
#     pickle.dump(model, file)

# %% [markdown]
# # END RNN

# %% [markdown]
# ## ANN START

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import backend as K
from tensorflow.keras.optimizers import RMSprop

# %%
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
model = Sequential()

model.add(Dense(units=16, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.5))
model.add(Dense(units=8, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=6, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=1, activation='linear'))

# %%
optimizer = RMSprop()

# %%
# model.compile(optimizer=optimizer, loss=root_mean_squared_error)

model.compile(loss='mean_squared_error', optimizer='adam')
# model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae', 'rmse'])

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_21 (Dense)            (None, 16)                64
#
#  dropout_16 (Dropout)        (None, 16)                0
#
#  dense_22 (Dense)            (None, 8)                 136
#
#  dropout_17 (Dropout)        (None, 8)                 0
#
#  dense_23 (Dense)            (None, 6)                 54
#
#  dropout_18 (Dropout)        (None, 6)                 0
#
#  dense_24 (Dense)            (None, 1)                 7
#
# ...
# Total params: 261
# Trainable params: 261
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    X_train,y_train,  
    epochs=2000,
    validation_split=0.2
)
# Out:
# Epoch 1/2000
# 24/24 [==============================] - 1s 9ms/step - loss: 34.8002 - val_loss: 35.0985
# Epoch 2/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 32.9304 - val_loss: 33.4327
# Epoch 3/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 30.4553 - val_loss: 30.7150
# Epoch 4/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 27.3933 - val_loss: 26.7838
# Epoch 5/2000
# 24/24 [==============================] - 0s 3ms/step - loss: 22.8638 - val_loss: 21.3616
# Epoch 6/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 18.5501 - val_loss: 15.5013
# Epoch 7/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 14.9966 - val_loss: 10.9948
# Epoch 8/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 13.3602 - val_loss: 9.6934
# Epoch 9/2000
# 24/24 [==============================] - 0s 4ms/step - loss: 13.3560 - val_loss: 9.0731
# Epoch 10/2000
# ...

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
len(history.history['val_loss'])
# Out:
# 2000

# %%
loss_per_epoch = history.history['val_loss']
plt.figure(figsize=(10, 3))
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)
plt.show()

# %%
prediction = model.predict(X_test)
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd27c6ad4c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error( prediction,y_test)
rmse = sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 1.8062188198694573

# %%
# import pickle
# with open('ANN_1.4934206256113232.pk', 'wb') as file:
#     pickle.dump(model, file)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = range(len(loss_per_epoch))
y1 = history.history['loss']
y2 = history.history['val_loss']


fig, ax = plt.subplots()
ax.plot(x, y1, label='loss')

ax.plot(x, y2, label='val_loss')

ax.set_xlabel('NO OF ITERATION')
ax.set_ylabel('THE ACCURACY VALUE')
ax.set_title('Two Datasets on Same Graph')
ax.legend()


plt.show()

# %% [markdown]
# ## ANN END

# %% [markdown]
# ##### ANN USING LeakyReLU ACTIVATION

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU

# %%
model = Sequential()
model.add(Dense(units=64, input_dim=X_train.shape[1]))
model.add(LeakyReLU(alpha=0.1))  
model.add(Dense(units=32))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(units=16))
model.add(LeakyReLU(alpha=0.1))
model.add(Dense(units=1, activation='linear'))
model.compile(optimizer='adam', loss='mse')

# %%
history = model.fit(
    X_train,y_train,  
    epochs=200,
    validation_split=0.1
)
# Out:
# Epoch 1/200
# 9/9 [==============================] - 1s 21ms/step - loss: 35.5219 - val_loss: 38.4844
# Epoch 2/200
# 9/9 [==============================] - 0s 6ms/step - loss: 31.6584 - val_loss: 34.4193
# Epoch 3/200
# 9/9 [==============================] - 0s 6ms/step - loss: 27.9173 - val_loss: 29.5200
# Epoch 4/200
# 9/9 [==============================] - 0s 5ms/step - loss: 23.1962 - val_loss: 23.5025
# Epoch 5/200
# 9/9 [==============================] - 0s 10ms/step - loss: 17.9790 - val_loss: 16.5631
# Epoch 6/200
# 9/9 [==============================] - 0s 9ms/step - loss: 12.2633 - val_loss: 10.1203
# Epoch 7/200
# 9/9 [==============================] - 0s 9ms/step - loss: 8.0284 - val_loss: 6.0653
# Epoch 8/200
# 9/9 [==============================] - 0s 11ms/step - loss: 6.4041 - val_loss: 5.2199
# Epoch 9/200
# 9/9 [==============================] - 0s 10ms/step - loss: 6.2403 - val_loss: 4.8771
# Epoch 10/200
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x = range(len(history.history['loss']))
y1 = history.history['loss']
y2 = history.history['val_loss']


fig, ax = plt.subplots()
ax.plot(x, y1, label='loss')

ax.plot(x, y2, label='val_loss')

ax.set_xlabel('NO OF ITERATION')
ax.set_ylabel('THE ACCURACY VALUE')
ax.set_title('Two Datasets on Same Graph')
ax.legend()


plt.show()

# %%
# mse = model.evaluate(X_test, y_test)  
y_pred = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 67ms/step

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

mse = mean_squared_error( y_pred,y_test)
rmse = sqrt(mse)
print("RMSE:", rmse)
# Out:
# RMSE: 1.4801817814611868
